# %%
# install.packages('readxl')
library(readxl)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"

# %%
reservation_r <- read_excel('reservation_r.xlsx')

# %%
order_info_r <- read_excel('order_info_r.xlsx')

# %%
head(reservation_r)
# Out:
#   RESERV_NO  RESERV_DATE RESERV_TIME CUSTOMER_ID BRANCH VISITOR_CNT CANCEL
# 1 2019082701 20190827    1800        W1340914    마포   2           N
# 2 2019082602 20190826    1200        W341658     동작   5           N
# 3 2019082601 20190826    1800        W1328993    강북   4           N
# 4 2019082501 20190825    1800        W1340463    용산   2           N
# 5 2019082401 20190824    1200        W1344912    강동   3           N
# 6 2019082301 20190823    1800        W1344753    영등포 2           N

# %%
head(order_info_r)
# Out:
#   ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1 191228137840110010 M0003   2019122805  1        17000
# 2 191228137837810010 M0001   2019122806 10       240000
# 3 191228547385810010 M0003   2019122807  2        34000
# 4 191228567831310010 M0008   2019122808  1        10000
# 5 191228567430310010 M0005   2019122809  4       140000
# 6 191228137860010010 M0005   2019122810  2        70000

# %%
# dplyr를 불러와야 파이프연산자 사용가능.
library(dplyr)
bind_cols(order_info_r, tmp_order_info_r) # 테이블 열 붙이기.
# Out:
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES  ORDER_NO1
# 1   191228137840110010 M0003   2019122805  1        17000 191228137840110010
# 2   191228137837810010 M0001   2019122806 10       240000 191228137837810010
# 3   191228547385810010 M0003   2019122807  2        34000 191228547385810010
# 4   191228567831310010 M0008   2019122808  1        10000 191228567831310010
# 5   191228567430310010 M0005   2019122809  4       140000 191228567430310010
# 6   191228137860010010 M0005   2019122810  2        70000 191228137860010010
# 7   191228137860010010 M0009   2019122810  2        16000 191228137860010010
# 8   191229107864610010 M0005   2019122901  4       140000 191229107864610010
# 9   191229107864610010 M0009   2019122901  4        32000 191229107864610010
# 10  191229137425710010 M0003   2019122902  2        34000 191229137425710010
# 11  191230137860610010 M0003   2019123002  3        51000 191230137860610010
# ...

# %%
tmp_order_info_r <- order_info_r
bind_rows(order_info_r, tmp_order_info_r)
#테이블 행 붙이기
# Out:
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1   191228137840110010 M0003   2019122805  1        17000
# 2   191228137837810010 M0001   2019122806 10       240000
# 3   191228547385810010 M0003   2019122807  2        34000
# 4   191228567831310010 M0008   2019122808  1        10000
# 5   191228567430310010 M0005   2019122809  4       140000
# 6   191228137860010010 M0005   2019122810  2        70000
# 7   191228137860010010 M0009   2019122810  2        16000
# 8   191229107864610010 M0005   2019122901  4       140000
# 9   191229107864610010 M0009   2019122901  4        32000
# 10  191229137425710010 M0003   2019122902  2        34000
# 11  191230137860610010 M0003   2019123002  3        51000
# 12  191230137865010010 M0001   2019123003  8       192000
# 13  191230137847710020 M0005   2019123005  2        70000
# 14  191230187379710010 M0005   2019123006  1        35000
# 15  191230187379710010 M0009   2019123006  1         8000
# ...

# %%
#inner_join()함수 :일치하는 데이터 연결

inner_join(reservation_r, order_info_r, by = 'RESERV_NO')  %>%  arrange(RESERV_NO, ITEM_ID)
# Out:
#     RESERV_NO  RESERV_DATE RESERV_TIME CUSTOMER_ID BRANCH VISITOR_CNT CANCEL
# 1   2019060301 20190603    1800        W1327803    서초   4           N
# 2   2019060601 20190606    1800        W1328432    마포   4           N
# 3   2019060601 20190606    1800        W1328432    마포   4           N
# 4   2019060701 20190607    1800        W1328432    종로   4           N
# 5   2019061601 20190616    1200        W1330464    서대문 3           N
# 6   2019061801 20190618    1800        W1327595    영등포 2           N
# 7   2019062001 20190620    1200        W1331108    광진   1           N
# 8   2019062201 20190622    1800        W1328505    강남   2           N
# 9   2019062601 20190626    1200        W1333008    중구   1           N
# 10  2019062901 20190629    1800        W1330211    서초   4           N
# 11  2019062901 20190629    1800        W1330211    서초   4           N
# 12  2019070101 20190701    1800        W1331124    양천   2           N
# ...

# %%
#오른쪽 기준 모든 데이터 연결
right_join(reservation_r, order_info_r, by = "RESERV_NO") %>%
    arrange(RESERV_NO, ITEM_ID) %>%
    select(RESERV_NO, CUSTOMER_ID, VISITOR_CNT, CANCEL, ORDER_NO, ITEM_ID, SALES)
# Out:
#     RESERV_NO  CUSTOMER_ID VISITOR_CNT CANCEL ORDER_NO           ITEM_ID SALES
# 1   2019060301 W1327803    4           N      190603578341100100 M0005   140000
# 2   2019060601 W1328432    4           N      190606607189610010 M0005   140000
# 3   2019060601 W1328432    4           N      190606607189610010 M0010    12000
# 4   2019060701 W1328432    4           N      190607671896100100 M0001    48000
# 5   2019061601 W1330464    3           N      190616137200510010 M0005   105000
# 6   2019061801 W1327595    2           N      190618107186310010 M0001    48000
# 7   2019062001 W1331108    1           N      190620137203810010 M0008    10000
# 8   2019062201 W1328505    2           N      190622378311100100 M0001    48000
# 9   2019062601 W1333008    1           N      190626578341100100 M0009     8000
# 10  2019062901 W1330211    4           N      190629107832810010 M0002    24000
# 11  2019062901 W1330211    4           N      190629107832810010 M0007    30000
# ...

# %%
#왼쪽 기준 모든 데이터 연결
left_join(reservation_r, order_info_r, by = "RESERV_NO") %>%
    arrange(RESERV_NO, ITEM_ID) %>%
    select(RESERV_NO, CUSTOMER_ID, VISITOR_CNT, CANCEL, ORDER_NO, ITEM_ID, SALES)
# Out:
#     RESERV_NO  CUSTOMER_ID VISITOR_CNT CANCEL ORDER_NO           ITEM_ID SALES
# 1   2019060301 W1327803    4           N      190603578341100100 M0005   140000
# 2   2019060601 W1328432    4           N      190606607189610010 M0005   140000
# 3   2019060601 W1328432    4           N      190606607189610010 M0010    12000
# 4   2019060701 W1328432    4           N      190607671896100100 M0001    48000
# 5   2019061501 W1330211    4           Y      NA                 NA          NA
# 6   2019061601 W1330464    3           N      190616137200510010 M0005   105000
# 7   2019061602 W1330463    3           Y      NA                 NA          NA
# 8   2019061801 W1327595    2           N      190618107186310010 M0001    48000
# 9   2019062001 W1331108    1           N      190620137203810010 M0008    10000
# 10  2019062201 W1328505    2           N      190622378311100100 M0001    48000
# 11  2019062601 W1333008    1           N      190626578341100100 M0009     8000
# ...

# %%
#full_join()함수, 양쪽 테이블의 모든 데이터를 연결

table_added_row <- order_info_r %>%
    add_row(ORDER_NO = "1", ITEM_ID = "1", RESERV_NO = "1", SALES = 1)
full_join(reservation_r, table_added_row, by = "RESERV_NO") %>%
    arrange(RESERV_NO, ITEM_ID) %>%
    select(RESERV_NO, CUSTOMER_ID, VISITOR_CNT, CANCEL, ORDER_NO, ITEM_ID, SALES)
# Out:
#     RESERV_NO  CUSTOMER_ID VISITOR_CNT CANCEL ORDER_NO           ITEM_ID SALES
# 1   1          NA          NA          NA     1                  1            1
# 2   2019060301 W1327803     4          N      190603578341100100 M0005   140000
# 3   2019060601 W1328432     4          N      190606607189610010 M0005   140000
# 4   2019060601 W1328432     4          N      190606607189610010 M0010    12000
# 5   2019060701 W1328432     4          N      190607671896100100 M0001    48000
# 6   2019061501 W1330211     4          Y      NA                 NA          NA
# 7   2019061601 W1330464     3          N      190616137200510010 M0005   105000
# 8   2019061602 W1330463     3          Y      NA                 NA          NA
# 9   2019061801 W1327595     2          N      190618107186310010 M0001    48000
# 10  2019062001 W1331108     1          N      190620137203810010 M0008    10000
# 11  2019062201 W1328505     2          N      190622378311100100 M0001    48000
# ...

# %%
#-------------------------------------------------------------------

# %%
reservation_r_rsv_no <-select(reservation_r, RESERV_NO)
# reservation_r에서 rsv_no을 세로로 뽑아냄.

# %%
head(reservation_r_rsv_no)
# Out:
#   RESERV_NO
# 1 2019082701
# 2 2019082602
# 3 2019082601
# 4 2019082501
# 5 2019082401
# 6 2019082301

# %%
order_info_r_rsv_no <- select(order_info_r, RESERV_NO)

# %%
#intersection()함수 : 교집합, 예약도 하고 주문도 한 사람들 예약번호.
intersect(reservation_r_rsv_no, order_info_r_rsv_no)
# Out:
#     RESERV_NO
# 1   2019082701
# 2   2019082602
# 3   2019082601
# 4   2019082501
# 5   2019082401
# 6   2019082301
# 7   2019082202
# 8   2019082101
# 9   2019081901
# 10  2019081802
# 11  2019081801
# 12  2019081703
# 13  2019081702
# 14  2019081701
# 15  2019081602
# 16  2019081601
# 17  2019081502
# 18  2019081302
# 19  2019081301
# 20  2019081101
# 21  2019080801
# 22  2019080701
# 23  2019080602
# 24  2019080601
# 25  2019080501
# 26  2019080401
# 27  2019080203
# 28  2019080202
# 29  2019080201
# 30  2019080101
# ... ...
# 308 2019101602
# 309 2019101601
# 310 2019101304
# 311 2019101302
# 312 2019101301
# 313 2019101201
# 314 2019101101
# 315 2019101001
# 316 2019100802
# 317 2019100801
# 318 2019100701
# 319 2019100602
# 320 2019100503
# 321 2019100502
# 322 2019100501
# 323 2019100403
# 324 2019100402
# 325 2019100401
# 326 2019100301
# 327 2019092901
# 328 2019092601
# 329 2019092501
# 330 2019092301
# 331 2019092201
# 332 2019092001
# 333 2019091901
# 334 2019091801
# ...

# %%
#setdiff()함수 : 데이터 빼기 , 예약은 하고 주문은 안 한 예약번호들

setdiff(reservation_r_rsv_no, order_info_r_rsv_no)
# Out:
#    RESERV_NO
# 1  2019082201
# 2  2019081501
# 3  2019080102
# 4  2019073101
# 5  2019072601
# 6  2019072001
# 7  2019071301
# 8  2019070701
# 9  2019070301
# 10 2019061602
# 11 2019061501
# 12 2019100903
# 13 2019100902
# 14 2019100901
# 15 2019081403
# 16 2019081402
# 17 2019081401
# 18 2019091302
# 19 2019091301
# 20 2019090402
# 21 2019090401
# 22 2019090102
# 23 2019123004
# 24 2019123001
# 25 2019122705
# 26 2019111501
# 27 2019111502
# 28 2019122303
# 29 2019121802
# 30 2019121801
# 31 2019121703
# 32 2019121601
# 33 2019121306
# 34 2019121305
# 35 2019121201
# 36 2019120805
# 37 2019120804
# 38 2019120801
# 39 2019120601
# 40 2019120502
# 41 2019120305
# 42 2019120303
# 43 2019120204
# 44 2019120203
# 45 2019112904
# 46 2019112302
# 47 2019112301
# 48 2019111905
# 49 2019111801
# 50 2019111102
# 51 2019110803
# 52 2019110802
# 53 2019110801
# 54 2019110402
# 55 2019103001
# 56 2019102203
# 57 2019102001
# 58 2019101303
# 59 2019100601

# %%
#union()함수 : 합집합, 중복을 제거하여 데이터 합치기
union(reservation_r_rsv_no, order_info_r_rsv_no)
# Out:
#     RESERV_NO
# 1   2019082701
# 2   2019082602
# 3   2019082601
# 4   2019082501
# 5   2019082401
# 6   2019082301
# 7   2019082202
# 8   2019082201
# 9   2019082101
# 10  2019081901
# 11  2019081802
# 12  2019081801
# 13  2019081703
# 14  2019081702
# 15  2019081701
# 16  2019081602
# 17  2019081601
# 18  2019081502
# 19  2019081501
# 20  2019081302
# 21  2019081301
# 22  2019081101
# 23  2019080801
# 24  2019080701
# 25  2019080602
# 26  2019080601
# 27  2019080501
# 28  2019080401
# 29  2019080203
# 30  2019080202
# ... ...
# 367 2019101304
# 368 2019101303
# 369 2019101302
# 370 2019101301
# 371 2019101201
# 372 2019101101
# 373 2019101001
# 374 2019100802
# 375 2019100801
# 376 2019100701
# 377 2019100602
# 378 2019100601
# 379 2019100503
# 380 2019100502
# 381 2019100501
# 382 2019100403
# 383 2019100402
# 384 2019100401
# 385 2019100301
# 386 2019092901
# 387 2019092601
# 388 2019092501
# 389 2019092301
# 390 2019092201
# 391 2019092001
# 392 2019091901
# 393 2019091801
# ...

# %%
#----------------------------------------------

# %%
reservation_r %>%  #테이블 데이터 던지기
group_by(CUSTOMER_ID)  %>%  # 고객 아이디에 따른 그룹화
summarise(avg = mean(VISITOR_CNT))  %>%  #데이터 요약
filter(avg >= 3) %>%  # 특정조건에 따른 (요약값이 3이상만) 행 필터링
arrange(desc(avg)) #평균을 내림차순 정렬
# Out:
#     CUSTOMER_ID avg
# 1   W357565     13.500000
# 2   W1373867    12.000000
# 3   W359156     12.000000
# 4   W365779     12.000000
# 5   W363739     11.333333
# 6   W1375678    11.000000
# 7   W335138      9.000000
# 8   W346987      9.000000
# 9   W1356560     8.666667
# 10  W1375244     8.500000
# 11  W1339795     8.000000
# 12  W1340601     8.000000
# 13  W1356173     8.000000
# 14  W1376256     8.000000
# 15  W1376748     8.000000
# 16  W350657      8.000000
# 17  W355440      8.000000
# 18  W367946      8.000000
# 19  W371982      7.500000
# 20  W335276      7.000000
# 21  W348551      7.000000
# 22  W351513      7.000000
# 23  W1337923     6.875000
# 24  W1337927     6.500000
# 25  W1365311     6.500000
# 26  W1369282     6.500000
# 27  W1359422     6.000000
# 28  W1359682     6.000000
# 29  W1367062     6.000000
# 30  W1369439     6.000000
# ... ...         ...
# 84  W1330024    3
# 85  W1330463    3
# 86  W1330464    3
# 87  W1333818    3
# 88  W1334299    3
# ...

# %%
#------------------------------

# %%
# order_info_r 테이블의 메뉴(item_id)별, 월별 평균 매출을 계산한 후 
# 메뉴별, 월별로 오름차순 정렬해서 출력하는 메뉴 아이템별 월 평균 매출

my_first_cook <- order_info_r  %>% 
mutate(reserve_month = substr(RESERV_NO, 1, 6 ))  %>% 
group_by(ITEM_ID, reserve_month )  %>% 
summarise(avg_sales = mean(SALES))  %>% 
arrange(ITEM_ID, reserve_month )

my_first_cook
# Out:
#     ITEM_ID reserve_month avg_sales
# 1   M0001   201906         48000.00
# 2   M0001   201907         68000.00
# 3   M0001   201908         56000.00
# 4   M0001   201909         66000.00
# 5   M0001   201910         92000.00
# 6   M0001   201911         68307.69
# 7   M0001   201912        153142.86
# 8   M0002   201906         24000.00
# 9   M0002   201907         38000.00
# 10  M0002   201908         21600.00
# 11  M0002   201909         24000.00
# 12  M0002   201910         37333.33
# 13  M0002   201911         49200.00
# 14  M0002   201912         34736.84
# 15  M0003   201907         25500.00
# 16  M0003   201908         27200.00
# 17  M0003   201909         29750.00
# 18  M0003   201910         48875.00
# 19  M0003   201911         36266.67
# 20  M0003   201912         31875.00
# 21  M0004   201907         58333.33
# 22  M0004   201908         56250.00
# 23  M0004   201909         75000.00
# 24  M0004   201910         66666.67
# 25  M0004   201911         85000.00
# ...

# %%
#------------------------mpg

# %%
mpg <- as.data.frame(ggplot2:: mpg)

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
#Q.배기량이 4이하인 자동차, 5이상인 자동차, 어떤 자동차의 연비가 평균적으로 더 높은지 ?

car_4 <- mpg  %>%  
filter(displ <= 4) 


car_5 <-mpg  %>% 
filter(displ >= 5)


#정답: car_4 , 배기량이 4이하인 자동차의 연비가 평균적으로 더 높다.

# %%
mean(car_4$hwy)
# Out:
# [1] 25.96319

# %%
mean(car_5$hwy)
# Out:
# [1] 18.07895
